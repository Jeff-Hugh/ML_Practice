# %% [markdown]
# # scikit-learn-pca

# %% [markdown]
# Credits: Forked from [PyCon 2015 Scikit-learn Tutorial](https://github.com/jakevdp/sklearn_pycon2015) by Jake VanderPlas

# %% [markdown]
# ## Dimensionality Reduction: PCA
#
# ## 降维：PCA

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn; 
from sklearn import neighbors, datasets

import pylab as pl

seaborn.set()

iris = datasets.load_iris()

X, y = iris.data, iris.target
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(X)
X_reduced = pca.transform(X)
print("Reduced dataset shape:", X_reduced.shape)

import pylab as pl
pl.scatter(X_reduced[:, 0], X_reduced[:, 1], c=y,
           cmap='RdYlBu')

print("Meaning of the 2 components:")
for component in pca.components_:
    print(" + ".join("%.3f x %s" % (value, name)
                     for value, name in zip(component,
                                            iris.feature_names)))
# Out:
# Reduced dataset shape: (150, 2)
# Meaning of the 2 components:
# 0.361 x sepal length (cm) + -0.085 x sepal width (cm) + 0.857 x petal length (cm) + 0.358 x petal width (cm)
# 0.657 x sepal length (cm) + 0.730 x sepal width (cm) + -0.173 x petal length (cm) + -0.075 x petal width (cm)

# %% [markdown]
# # Dimensionality Reduction: Principal Component Analysis in-depth 降维：深入主成分分析
#
# Here we'll explore **Principal Component Analysis**, which is an extremely useful linear dimensionality reduction technique.  Principal Component Analysis is a very powerful unsupervised method for *dimensionality reduction* in data.  Look for directions in the data with the most variance. 这里我们将探讨**主成分分析**，这是一种极其有用的线性降维技术。主成分分析是一种非常强大的无监督数据降维方法。它可以在数据中寻找方差最大的方向。
#
# Useful to explore data, visualize data and relationships.它有助于探索数据、可视化数据及其关系。
#
# It's easiest to visualize by looking at a two-dimensional dataset:最简单的可视化方法是查看二维数据集：

# %%
np.random.seed(1)
X = np.dot(np.random.random(size=(2, 2)), np.random.normal(size=(2, 200))).T
plt.plot(X[:, 0], X[:, 1], 'o')
plt.axis('equal');

# %% [markdown]
# We can see that there is a definite trend in the data. What PCA seeks to do is to find the **Principal Axes** in the data, and explain how important those axes are in describing the data distribution:
#
# 我们可以看到数据中存在明显的趋势。PCA 旨在寻找数据中的 **主轴**，并解释这些轴在描述数据分布方面的重要性：

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(X)
print(pca.explained_variance_)
print(pca.components_)
# Out:
# [0.7625315 0.0184779]
# [[ 0.94446029  0.32862557]
#  [-0.32862557  0.94446029]]

# %%
plt.plot(X[:, 0], X[:, 1], 'o', alpha=0.5)
for length, vector in zip(pca.explained_variance_ratio_, pca.components_):
    v = vector * 3 * np.sqrt(length)
    plt.plot([0, v[0]], [0, v[1]], '-k', lw=3)
plt.axis('equal');

# %% [markdown]
# Notice that one vector is longer than the other. In a sense, this tells us that that direction in the data is somehow more "important" than the other direction. 注意，一个向量比另一个向量长。从某种意义上说，这告诉我们数据中的这个方向比另一个方向更“重要”。
# The explained variance quantifies this measure of "importance" in direction.解释方差量化了方向的“重要性”。
#
# Another way to think of it is that the second principal component could be **completely ignored** without much loss of information! Let's see what our data look like if we only keep 95% of the variance: 另一种理解是，第二个主成分可以**完全忽略**，而不会造成太多信息损失！让我们看看，如果我们只保留 95% 的方差，数据会是什么样子：

# %%
clf = PCA(0.95) # keep 95% of variance
X_trans = clf.fit_transform(X)
print(X.shape)
print(X_trans.shape)
# Out:
# (200, 2)
# (200, 1)

# %% [markdown]
# Isomap: manifold learning, good when PCA doesn't work like in a loop.  Large number of datasets, can use randomized PCA. Isomap：流形学习，当 PCA 无法像循环一样工作时非常有用。大量数据集时，可以使用随机 PCA。

# %% [markdown]
# By specifying that we want to throw away 5% of the variance, the data is now compressed by a factor of 50%! Let's see what the data look like after this compression: 通过指定我们要丢弃 5% 的方差，数据现在被压缩了 50%！让我们看看压缩后的数据是什么样子的：

# %%
X_new = clf.inverse_transform(X_trans)
plt.plot(X[:, 0], X[:, 1], 'o', alpha=0.2)
plt.plot(X_new[:, 0], X_new[:, 1], 'ob', alpha=0.8)
plt.axis('equal');

# %% [markdown]
# The light points are the original data, while the dark points are the projected version.  We see that after truncating 5% of the variance of this dataset and then reprojecting it, the "most important" features of the data are maintained, and we've compressed the data by 50%!
# 浅色点是原始数据，而深色点是投影版本。我们看到，在截断该数据集 5% 的方差然后重新投影之后，数据的“最重要”特征得以保留，并且我们将数据压缩了 50%！
#
# This is the sense in which "dimensionality reduction" works: if you can approximate a data set in a lower dimension, you can often have an easier time visualizing it or fitting complicated models to the data.
#
# 这就是“降维”的意义所在：如果可以在较低维度上近似数据集，通常可以更轻松地对其进行可视化或将复杂模型拟合到数据中。
