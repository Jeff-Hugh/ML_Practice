# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn
import pandas as pd

# %%
# 读取excel数据，第一行为列名
file = "data/data.xlsx"
data = pd.read_excel(file, header=0)

# 截取数据的第7列至“总通最大值”
data = data.iloc[:, 6:-3]

# 打印数据的前几行
print(data.head())
# Out:
#    重量平均值    重量相对偏差  重量标准偏差  重量变异系数  重量最小值  重量最大值  吸阻平均值    吸阻相对偏差  吸阻标准偏差  \
# 0  0.516  0.006524   0.011   2.202  0.499  0.538  1.275  0.041404   0.048
# 1  0.515  0.004573   0.012   2.350  0.482  0.545  1.321  0.006820   0.046
# 2  0.507  0.011032   0.012   2.316  0.477  0.524  1.291  0.029375   0.049
# 3  0.507  0.011032   0.013   2.549  0.479  0.529  1.296  0.025616   0.059
# 4  0.509  0.007131   0.009   1.863  0.486  0.531  1.350  0.014984   0.058
#
#    吸阻变异系数  ...  嘴通平均值  嘴通标准偏差  嘴通变异系数  嘴通最小值  嘴通最大值  总通平均值  总通标准偏差  总通变异系数  \
# 0   3.784  ...   38.0   2.073   5.453   33.7   41.4   44.6   2.006   4.502
# 1   3.465  ...   36.1   2.202   6.105   31.3   39.6   43.0   2.106   4.904
# 2   3.802  ...   34.8   1.802   5.184   30.9   37.4   42.0   1.810   4.308
# 3   4.587  ...   36.3   1.884   5.196   31.4   41.4   42.8   2.027   4.739
# 4   4.322  ...   36.3   1.598   4.407   33.1   39.9   42.0   1.577   3.751
#
#    总通最小值  总通最大值
# 0   40.1   48.0
# 1   37.8   47.0
# 2   38.4   45.3
# 3   36.8   47.5
# 4   38.4   45.6
#
# [5 rows x 40 columns]

# %%
# 检查并处理缺失值（NaNs）和异常值（outliers）
def preprocess_data(df):
    # 检查缺失值
    if df.isnull().values.any():
        # 如果存在缺失值，打印缺失值的索引
        print("缺失值的索引：")
        print(df[df.isnull().any(axis=1)].index.tolist())

        print("数据中存在缺失值，正在处理...")

        df = df.fillna(df.mean())  # 用均值填充缺失值
        print("缺失值已处理。")
    else:
        print("数据中没有缺失值。")

    # 检查异常值
    for column in df.select_dtypes(include=[np.number]).columns:
        if (df[column] < 0).any():
            print(f"列 {column} 存在异常值（负数），正在处理...")
            df[column] = df[column].clip(lower=0)

    print("异常值已处理。")
    return df

data = preprocess_data(data)
# Out:
# 缺失值的索引：
# [592, 593, 758, 759, 760, 761, 762, 763, 764, 765, 766, 767]
# 数据中存在缺失值，正在处理...
# 缺失值已处理。
# 异常值已处理。

# %% [markdown]
# ## 利用多层感知机进行回归预测

# %%
from sklearn.model_selection import train_test_split
# x = data.drop(data.columns[30], axis=1)  # 除第30列外的所有列
x = data.iloc[:, :30]                     # 前30列
y = data.iloc[:, 30]                     # 第30列
print(x.shape)
print(y.shape)
# Out:
# (1237, 30)
# (1237,)

# %%
# 将训练集和测试集划分为80%和20%
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, r2_score

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (989, 30) (989,)
# (248, 30) (248,)

# %%
# 进行Z-score标准化
from sklearn.preprocessing import StandardScaler, MinMaxScaler
print("原始数据的统计信息:")
print(x_train.describe())

# 2. 创建并使用 StandardScaler
# 创建StandardScaler的实例
scaler_x = StandardScaler()
scaler_y = StandardScaler()

# 使用 .fit_transform() 一步完成拟合和转换
# 注意：StandardScaler的输出是一个NumPy数组，而不是Pandas DataFrame
scaled_x_train = scaler_x.fit_transform(x_train)
scaled_y_train = scaler_y.fit_transform(y_train.values.reshape(-1, 1))

# 为了方便查看，可以将其转换回DataFrame
scaled_x_pd = pd.DataFrame(scaled_x_train, columns=x_train.columns)
scaled_y_pd = pd.DataFrame(scaled_y_train, columns=[y_train.name])

print("\n-------------------------------------------------")
print("\n标准化后数据的统计信息:")
print(scaled_x_pd.describe())
print(scaled_y_pd.describe())
# Out:
# 原始数据的统计信息:
#             重量平均值      重量相对偏差      重量标准偏差      重量变异系数       重量最小值       重量最大值  \
# count  989.000000  989.000000  989.000000  989.000000  989.000000  989.000000
# mean     0.512730    0.007128    0.010455    2.042367    0.490773    0.534329
# std      0.004709    0.005791    0.001509    0.290115    0.007012    0.007262
# min      0.501000    0.000087    0.005000    1.006000    0.466000    0.517000
# 25%      0.510000    0.002623    0.009000    1.839000    0.486000    0.529000
# 50%      0.512000    0.005375    0.010300    2.044500    0.491000    0.533000
# 75%      0.515600    0.010425    0.011000    2.218000    0.495000    0.538900
# max      0.531000    0.035783    0.017100    3.304200    0.518000    0.560000
#
#             吸阻平均值      吸阻相对偏差      吸阻标准偏差      吸阻变异系数  ...      长度标准偏差  \
# count  989.000000  989.000000  989.000000  989.000000  ...  989.000000
# mean     1.330534    0.019631    0.049924    3.750674  ...    0.160261
# std      0.033947    0.016303    0.008645    0.632823  ...    0.081353
# min      1.172553    0.000023    0.025000    1.974000  ...    0.080000
# 25%      1.311000    0.007465    0.044000    3.291000  ...    0.134000
# 50%      1.331000    0.015842    0.049913    3.725400  ...    0.152000
# 75%      1.353000    0.028114    0.056000    4.159000  ...    0.175000
# max      1.446000    0.118428    0.080000    5.970000  ...    1.985500
#
#            长度变异系数       长度最小值       长度最大值       硬度平均值      硬度相对偏差      硬度标准偏差  \
# count  989.000000  989.000000  989.000000  989.000000  989.000000  989.000000
# mean     0.178120   89.666505   90.345873   58.504279    0.016039    2.519193
# std      0.090722    0.441008    0.178461    1.197616    0.012799    0.412173
# min      0.089000   79.094300   89.899300   54.200000    0.000091    1.412600
# 25%      0.149000   89.621900   90.240000   57.700000    0.006685    2.247300
# 50%      0.169000   89.691300   90.330000   58.500000    0.013522    2.487000
# 75%      0.195000   89.760000   90.440000   59.200000    0.022370    2.745000
# max      2.216400   90.020000   91.632800   63.200000    0.080178    4.790000
#
#            硬度变异系数       硬度最小值       硬度最大值
# count  989.000000  989.000000  989.000000
# mean     4.307694   53.365987   63.952018
# std      0.709883    1.843891    2.227078
# min      2.425500   36.300000   58.100000
# 25%      3.843000   52.300000   62.600000
# 50%      4.262000   53.478500   63.700000
# 75%      4.696000   54.600000   64.900000
# max      8.188000   58.700000   82.766500
#
# [8 rows x 30 columns]
#
# -------------------------------------------------
#
# 标准化后数据的统计信息:
#               重量平均值        重量相对偏差        重量标准偏差        重量变异系数         重量最小值  \
# count  9.890000e+02  9.890000e+02  9.890000e+02  9.890000e+02  9.890000e+02
# mean  -2.439841e-14 -1.499755e-16 -2.334948e-17 -1.005824e-16 -5.943342e-15
# std    1.000506e+00  1.000506e+00  1.000506e+00  1.000506e+00  1.000506e+00
# min   -2.492208e+00 -1.216452e+00 -3.616344e+00 -3.574066e+00 -3.534915e+00
# 25%   -5.800823e-01 -7.783702e-01 -9.647294e-01 -7.013424e-01 -6.810704e-01
# 50%   -1.551655e-01 -3.028578e-01 -1.029545e-01  7.354791e-03  3.239070e-02
# 75%    6.096847e-01  5.695732e-01  3.610781e-01  6.056952e-01  6.031596e-01
# max    3.881544e+00  4.950389e+00  4.404791e+00  4.351617e+00  3.885081e+00
#
#               重量最大值         吸阻平均值        吸阻相对偏差        吸阻标准偏差        吸阻变异系数  \
# count  9.890000e+02  9.890000e+02  9.890000e+02  9.890000e+02  9.890000e+02
# mean  -2.730093e-16  1.345289e-15  1.796114e-17 -1.756600e-15  2.631307e-16
# std    1.000506e+00  1.000506e+00  1.000506e+00  1.000506e+00  1.000506e+00
# min   -2.387370e+00 -4.656044e+00 -1.203324e+00 -2.884597e+00 -2.808956e+00
# 25%   -7.342024e-01 -5.757031e-01 -7.465756e-01 -6.855777e-01 -7.267538e-01
# 50%   -1.831466e-01  1.374018e-02 -2.325296e-01 -1.242924e-03 -3.995902e-02
# 75%    6.296606e-01  6.621277e-01  5.205784e-01  7.032765e-01  6.455710e-01
# max    3.536480e+00  3.403039e+00  6.063086e+00  3.480985e+00  3.508797e+00
#
#        ...        长度标准偏差        长度变异系数         长度最小值         长度最大值  \
# count  ...  9.890000e+02  9.890000e+02  9.890000e+02  9.890000e+02
# mean   ... -1.248299e-16 -1.418930e-16  1.659071e-14 -5.598667e-14
# std    ...  1.000506e+00  1.000506e+00  1.000506e+00  1.000506e+00
# min    ... -9.870838e-01 -9.828316e-01 -2.398496e+01 -2.503624e+00
# 25%    ... -3.229728e-01 -3.211393e-01 -1.011944e-01 -5.935579e-01
# 50%    ... -1.016025e-01 -1.005752e-01  5.625205e-02 -8.899106e-02
# 75%    ...  1.812595e-01  1.861581e-01  2.121104e-01  5.277018e-01
# max    ...  2.244742e+01  2.247857e+01  8.019675e-01  7.214895e+00
#
#               硬度平均值        硬度相对偏差        硬度标准偏差        硬度变异系数         硬度最小值  \
# count  9.890000e+02  9.890000e+02  9.890000e+02  9.890000e+02  9.890000e+02
# mean  -3.682034e-16 -2.325968e-16  8.621348e-17 -4.346596e-16  2.087085e-15
# std    1.000506e+00  1.000506e+00  1.000506e+00  1.000506e+00  1.000506e+00
# min   -3.595856e+00 -1.246696e+00 -2.686137e+00 -2.652755e+00 -9.260105e+00
# 25%   -6.719060e-01 -7.312366e-01 -6.599914e-01 -6.549373e-01 -5.784110e-01
# 50%   -3.574603e-03 -1.968049e-01 -7.814501e-02 -6.440077e-02  6.105001e-02
# 75%    5.812154e-01  4.948898e-01  5.481227e-01  5.472767e-01  6.695825e-01
# max    3.922873e+00  5.013904e+00  5.512143e+00  5.468885e+00  2.894266e+00
#
#               硬度最大值
# count  9.890000e+02
# mean  -3.951451e-17
# std    1.000506e+00
# min   -2.628996e+00
# 25%   -6.073888e-01
# 50%   -1.132181e-01
# 75%    4.258772e-01
# max    8.452332e+00
#
# [8 rows x 30 columns]
#               嘴通平均值
# count  9.890000e+02
# mean   4.497470e-15
# std    1.000506e+00
# min   -3.712875e+00
# 25%   -6.772090e-01
# 50%    5.829387e-02
# 75%    7.019406e-01
# max    2.845360e+00

# %%
#----------------------开始训练----------------------
mlp = MLPRegressor(hidden_layer_sizes=(20, 10, 5, 2), max_iter=2000, activation='logistic',solver='adam', early_stopping=True, random_state=42)

mlp.fit(scaled_x_train, scaled_y_train.ravel())

#----------------------训练已完成----------------------
print("训练完成")
# Out:
# 训练完成

# %%
# --- 可视化训练损失和验证得分 ---
fig, ax1 = plt.subplots(figsize=(12, 7))

# 绘制训练损失曲线 (使用左侧Y轴)
color = 'tab:red'
ax1.set_xlabel('Iteration / Epoch', fontsize=12)
ax1.set_ylabel('Training Loss', color=color, fontsize=12)
ax1.plot(mlp.loss_curve_, color=color, label='Training Loss')
ax1.tick_params(axis='y', labelcolor=color)
ax1.grid(True, axis='x')

# 创建第二个Y轴，用于绘制验证得分
ax2 = ax1.twinx()  
color = 'tab:blue'
# 注意：validation_scores_ 是得分(如R^2)，不是损失。得分越高越好。
ax2.set_ylabel('Validation Score ($R^2$)', color=color, fontsize=12)  
ax2.plot(mlp.validation_scores_, color=color, label='Validation Score')
ax2.tick_params(axis='y', labelcolor=color)

fig.suptitle('Training Loss vs. Validation Score', fontsize=16)
fig.tight_layout(rect=[0, 0, 1, 0.96]) 
plt.show()

# %%
# 在测试集上进行预测
scaled_x_test = scaler_x.transform(x_test)
scaled_y_pred = mlp.predict(scaled_x_test)
y_pred = scaler_y.inverse_transform(scaled_y_pred.reshape(-1, 1)).ravel()

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R^2 Score: {r2}")

# 可视化
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, alpha=0.7)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=2)
plt.title("Actual vs Predicted", fontsize=16)
plt.xlabel("Actual", fontsize=12)
plt.ylabel("Predicted", fontsize=12)
plt.grid(True)
plt.show()
# Out:
# Mean Squared Error: 1.619802128680232
# R^2 Score: 0.002548036149858879
